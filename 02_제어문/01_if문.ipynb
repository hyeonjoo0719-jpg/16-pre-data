# %%
# if문은 왜 필요할까?
## 돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어가라
money = True
if money == True:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
# if문의 구조
# if 조건문:    # 조건문 자리는 True 또는 False를 판단하는 자리
#     수행할 문장1
#     수행할 문장2
# else:
#     수행할 문장3
#     수행할 문장4
# Out:
#   Cell In[5], line 14
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
# 만약 3000원 이상의 돈을 가지고 있으면, 택시를 타고 가고 그렇지 않으면 걸어가라
money = 3000

if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %%
# 돈이 3000원 이상 있거나, 카드가 있다면 택시를 타고 가고 그렇지 않으면 걸어가라"
money = 2000
card = True

if (money >= 3000) or (card == True):
    print("택시를 타고 가라")
else: 
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
eggs = True
if eggs == True:
    print("우유 6개 사와")
else:
    print("우유를 한 개 사와")
# Out:
# 우유 6개 사와

# %%
# 다양한 조건을 판단하는 elif
## 주머니에 돈이 있으면 택시를 타고 가고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고, 돈도 없고 카드도 없으면 걸어가라
pocket = ["paper", "phone"]
card = True

if "money" in pocket:
    print("1. 택시를 타고 가라")
elif "money" not in pocket and card == True:   # money가 포켓에 없다는 것을 전제하고 있음
    print("2. 택시를 타고 가라")
elif "money" not in pocket and card == False:
    print("걸어가라")


pocket = ["paper", "phone"]
card = True

if "money" in pocket:
    print("1. 택시를 타고 가라")
elif card == True:   # money가 포켓에 없다는 것을 전제하고 있음
    print("2. 택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 2. 택시를 타고 가라
# 2. 택시를 타고 가라

# %%
# Out:
# 2. 택시를 타고 가라
